# %% [markdown]
# # Web scraping on JobsDB

# %%
base URL - https://hk.jobsdb.com/hk/jobs/

# %% [markdown]
# **1. import library**

# %%
from bs4 import BeautifulSoup
import requests
from time import sleep
from random import randint
import re
import pandas as pd
from datetime import datetime

# %% [markdown]
# **2. get one department all pages**

# %%
# get all URL link
def URL_():
    URL_f = "https://hk.jobsdb.com/hk/jobs/information-technology/"
    html_f = requests.get(URL_f)
    function = BeautifulSoup(html_f.text, "html.parser")
    
    page = [i.text for i in function.select("option")]
    page_num = []
    
    for i in page:
        for j in i.split():
            if(j.isdigit()):
                page_num.append(j)
    URL_all = []
    for i in range(1,int(page_num[-1])+1):
        #URL_all = ("https://en.tripadvisor.com.hk/Restaurant_Review-g294217-d13283405-Reviews-or")
        #URL_b = ("-Yardbird-Hong_Kong.html")
        URL_combine = URL_f + str(i)
        URL_all.append(URL_combine)
    return URL_all

#activate function
URL_()
# Out:
# ['https://hk.jobsdb.com/hk/jobs/information-technology/1',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/2',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/3',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/4',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/5',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/6',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/7',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/8',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/9',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/10',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/11',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/12',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/13',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/14',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/15',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/16',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/17',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/18',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/19',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/20',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/21',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/22',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/23',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/24',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/25',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/26',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/27',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/28',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/29',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/30',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/31',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/32',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/33',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/34',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/35',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/36',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/37',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/38',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/39',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/40',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/41',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/42',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/43',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/44',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/45',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/46',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/47',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/48',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/49',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/50',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/51',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/52',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/53',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/54',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/55',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/56',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/57',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/58',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/59',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/60',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/61',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/62',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/63',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/64',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/65',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/66',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/67',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/68',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/69',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/70',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/71',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/72',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/73',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/74',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/75',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/76',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/77',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/78',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/79',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/80',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/81',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/82',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/83',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/84',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/85',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/86',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/87',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/88',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/89',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/90',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/91',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/92',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/93',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/94',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/95',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/96',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/97',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/98',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/99',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/100',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/101',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/102',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/103',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/104',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/105',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/106',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/107',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/108',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/109',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/110',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/111',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/112',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/113',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/114',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/115',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/116',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/117',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/118',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/119',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/120',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/121',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/122',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/123',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/124',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/125',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/126',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/127',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/128',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/129',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/130',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/131',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/132',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/133',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/134',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/135',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/136',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/137',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/138',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/139',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/140',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/141',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/142',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/143',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/144',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/145',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/146',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/147',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/148',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/149',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/150',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/151',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/152',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/153',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/154',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/155',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/156',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/157',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/158',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/159',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/160',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/161',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/162',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/163',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/164',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/165',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/166',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/167',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/168',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/169',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/170',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/171',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/172',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/173',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/174',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/175',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/176',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/177',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/178',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/179',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/180',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/181',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/182',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/183',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/184',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/185',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/186',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/187',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/188',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/189',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/190',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/191',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/192',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/193',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/194',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/195',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/196',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/197',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/198',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/199',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/200',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/201',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/202',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/203',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/204',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/205',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/206',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/207',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/208',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/209',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/210',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/211',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/212',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/213',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/214',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/215',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/216',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/217',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/218',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/219',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/220',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/221',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/222',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/223',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/224',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/225',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/226',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/227',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/228',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/229',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/230',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/231',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/232',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/233',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/234',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/235',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/236',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/237',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/238',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/239',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/240',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/241',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/242',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/243',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/244',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/245',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/246',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/247',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/248',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/249',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/250',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/251',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/252',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/253',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/254',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/255',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/256',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/257',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/258',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/259',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/260',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/261',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/262',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/263',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/264',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/265',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/266',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/267',
#  'https://hk.jobsdb.com/hk/jobs/information-technology/268']

# %% [markdown]
# **3. Get every Jobs page**

# %%
#just save links
links = []
for i in URL_():
    html_e = requests.get(i)
    everyjobpage = BeautifulSoup(html_e.text, "html.parser")
    links_all =[a['href'] for a in everyjobpage.select('a[href]')]
    r = re.compile(r'.*token=')
    joblinks = list(filter(r.match, links_all))
    links.append(joblinks)

job_page = []
for i in links:
    for j in i:
        basic_URL = "https://hk.jobsdb.com"
        URL_combine = basic_URL+j
        job_page.append(URL_combine)

job_page
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-1a0b030d72b4> in <module>
#       2 links = []
#       3 for i in URL_():
# ----> 4     html_e = requests.get(i)
#       5     everyjobpage = BeautifulSoup(html_e.text, "html.parser")
#       6     links_all =[a['href'] for a in everyjobpage.select('a[href]')]
#
# /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow_environment/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow_environment/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow_environment/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow_environment/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow_environment/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow_environment/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow_environment/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow_environment/lib/python3.8/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow_environment/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow_environment/lib/python3.8/http/client.py in getresponse(self)
#    1342         try:
#    1343             try:
# -> 1344                 response.begin()
#    1345             except ConnectionError:
#    1346                 self.close()
#
# /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow_environment/lib/python3.8/http/client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow_environment/lib/python3.8/http/client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow_environment/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow_environment/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow_environment/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# **4. On job page, get details**

# %%
#just save job details
startTime = datetime.now()

job_title = []
co_name = []
heading_info = []
job_highlights = []
job_d = []
add_info = []
co_overview = []
jobs = []

for i in job_page:
    html_d = requests.get(i)
    job = BeautifulSoup(html_d.text, "html.parser")
    #job title
    jt = job.h1.string
    job_title.append(jt)
    #co_name
    cn = job.find("div", {"data-automation":"detailsTitle"}).span.get_text()
    co_name.append(cn)
    #heading_info
    hi = [i.text for i in job.find_all(class_="FYwKg _11hx2_0")]
    heading_info.append(hi)
    #job_highlights
    jh = [i.text for i in job.find_all(class_="FYwKg _3VCZm _1uk_1 _3RqUb_0")]
    job_highlights.append(jh)
    #job_descriptions
    jd = job.find("div", {"data-automation":"jobDescription"}).get_text()
    job_d.append(jd)
    #Additional info
    ai = [i.text for i in job.find_all(class_="FYwKg _1uk_1 _2fqoM_0 _1hqiH_0")]
    add_info.append(ai)
    #company overview
    co = [i.text for i in job.find_all(class_="vDEj0_0")]
    co_overview.append(co)
    jobs_all=pd.DataFrame({
    "title":job_title,
    "company":co_name, 
    "heading info":heading_info,
    "job highlights":job_highlights,
    "job description":job_d,
    "additional information":add_info,
    "company overview":co_overview})
    #jobs.append(jobs_all)


print(datetime.now() - startTime)
# Out:
# 0:10:49.009126

# %% [markdown]
# **5. save as csv**

# %%
jobs_all.to_csv("sciences-lab-research-development.csv")
